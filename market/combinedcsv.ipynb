# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
from pandas import *

# %%
df = pd.read_csv('20210808.csv')

# %%
df.head(10)
# Out:
#    duration  is_buy_order                issued  location_id  min_volume  \
# 0        90          True  2021-07-24T06:44:53Z     60014437           1
# 1        90         False  2021-06-22T02:25:37Z     60014071           1
# 2        90         False  2021-05-22T14:13:15Z     60013867           1
# 3        90         False  2021-05-27T08:14:29Z     60013867           1
# 4        90         False  2021-06-13T15:04:45Z     60013867           1
# 5        90         False  2021-06-04T22:59:18Z     60012163           1
# 6        90         False  2021-06-22T02:07:43Z     60012136           1
# 7        90          True  2021-07-10T21:11:44Z     60014437           1
# 8        90         False  2021-06-26T10:47:10Z     60014437           1
# 9        90         False  2021-08-04T17:17:10Z     60013867           1
#
#      order_id   price   range  system_id  type_id  volume_remain  \
# 0  5980151223     5.3  region   30000001       18         241153
# ...

# %%
df = df.drop(['http_last_modified','issued','is_buy_order'], axis=1)

# %%
df.head(10)
# Out:
#    duration  location_id  min_volume    order_id   price   range  system_id  \
# 0        90     60014437           1  5980151223     5.3  region   30000001
# 1        90     60014071           1  6025877926  5000.0  region   30000017
# 2        90     60013867           1  6005466300  6000.0  region   30000019
# 3        90     60013867           1  6008912593  5999.0  region   30000019
# 4        90     60013867           1  6020507446  5999.0  region   30000019
# 5        90     60012163           1  6014715183  5000.0  region   30000044
# 6        90     60012136           1  6025871283  5000.0  region   30000102
# 7        90     60014437           1  6036855522    50.0  region   30000001
# 8        90     60014437           1  6028377466  1600.0  region   30000001
# 9        90     60013867           1  6052115250  1200.0  region   30000019
#
#    type_id  volume_remain  volume_total  region_id  station_id  \
# 0       18         241153        250000   10000001  60014437.0
# ...

# %%
df.to_csv("20210808.csv", encoding='utf-8', index=False)
